# %% [markdown]
# ## Exercise 4: Box and Whisker Plots

# %% [markdown]
# > 1. What is the range and interquartile range of the data set?
#
# - Median: $617,594$
# - Minimum: $216,290$
# - Maximum: $845,300$
# - First Quartile: $324,528$
# - Third Quartile: $790,390$

# %% [markdown]
# \begin{gather*}
#     R = 845,300 - 216,290 \\
#     R = 629,010 \\ \\
#
#     IQR = 790,390 - 324,528 \\
#     IQR = 465,862
# \end{gather*}

# %% [markdown]
# > 2. These are average lifespans in years of various mammals:
#
# ![image.png](attachment:image.png)
#
# Find the five-number summary for the data.

# %% [markdown]
# \begin{gather*}
#     10, 10, 14, 15, 18, 20, 35, 35, 40, 40 \\
#     \text{Min} = 10 \\
#     \text{Max} = 40 \\
#     \text{Q1} = 14 \\
#     \text{Q3} = 35 \\
#     \text{Median} = 19
# \end{gather*}

# %% [markdown]
# > 3. Create a box plot based on the following information about a data set.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > 4. How does the spread of data between $1$ and $5$ compare to the spread
# of data between $11$ and $12$?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q1 has a larger spread than Q3.

# %% [markdown]
# > 5. In which quarter of the data is the number $23$ located?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $23$ is located in Q3

# %% [markdown]
# > 6. Create the box-and-whisker plot for the book ratings given in the stem
# and leaf plot.
#
# ![image.png](attachment:image.png)
