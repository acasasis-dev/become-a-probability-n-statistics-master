# %% [markdown]
# ## Exercise 8: Weighted Means and Grouped Data

# %% [markdown]
# > 1. An investor purchases shares of a particular stock on the same date
# every month for $12$ months. He records the price and number of shares
# each month. Calculate the mean share price.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu = \frac{[(8)(30)] + [(10)(12)] + [(14)(10)] + [(9)(25)] + [(6)(35)] + [(13)(15)] + [(18)(10)] + [(21)(5)] + [(25)(7)] + [(27)(10)] + [(28)(8)] + [(31)(4)]}{30 + 12 + 10 + 25 + 35 + 15 + 10 + 5 + 7 + 10 + 8 + 4} \\
#         \mu = \frac{240 + 120 + 140 + 225 + 210 + 195 + 180 + 105 + 175 + 270 + 224 + 124}{171} \\
#         \mu = \frac{2208}{171} \\
#         \mu = 12.91 \\
# \end{gather*}

# %% [markdown]
# > 2. A chemistry course teacher weights class discussions at $0.05$, quizzes
# at $0.10$, and group projects at $0.40$. Given the grades for one student in the
# table below, calculate her final grade.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu = \frac{[(88)(0.1)] + [(92)(0.05)] + [(93)(0.1)] + [(90)(0.05)] + [(85)(0.1)] + [(94)(0.05)] + [(97)(0.1)] + [(80)(0.05)] + [(85)(0.4)]}{0.1 + 0.05 + 0.1 + 0.05 + 0.1 + 0.05 + 0.1 + 0.05 + 0.4} \\
#         \mu = \frac{8.8 + 4.6 + 9.3 + 4.5 + 8.5 + 4.7 + 9.7 + 4.0 + 34.0}{1.0} \\
#         \mu = \frac{88.1}{1.0} \\
#         \mu = 88.1 \\
# \end{gather*}

# %% [markdown]
# > 3. Given the dataset $\{12, 15, 8, 21, 25, 14, 16, 18, 10\}$, divide it into four
# groups and find the sample variance and standard deviation.

# %% [markdown]
# \begin{gather*}
#     R = 25 - 8 = 17 \\
#     \text{bin range} = \lfloor \frac{17}{4} \rfloor = \lfloor 4.25 \rfloor = 4 \\ \\
#
#     (8, 12): 3, (13, 17): 3, (18, 22): 2, (23, 27): 1 \\
# \\
#     \bar{\text{x}} = \frac{[(3)(10)] + [(3)(15)] + [(2)(20)] + [(1)(25)]}{3 + 3 + 2 + 1} \\
#     \bar{\text{x}} = \frac{30 + 45 + 40 + 25}{9} \\
#     \bar{\text{x}} = \frac{140.0}{9} \\
#     \bar{\text{x}} = 15.56
# \\
# \\
#     s^2_\text{xy} = \frac{[3(10.0 - 15.56)^2] + [3(15.0 - 15.56)^2] + [2(20.0 - 15.56)^2] + [1(25.0 - 15.56)^2]}{(3 + 3 + 2 + 1) - 1} \\
#     s^2_\text{xy} = \frac{[3(-5.56)^2] + [3(-0.56)^2] + [2(4.44)^2] + [1(9.44)^2]}{9 - 1} \\
#     s^2_\text{xy} = \frac{(3)(30.91) + (3)(0.31) + (2)(19.71) + (1)(89.11)}{8} \\
#     s^2_\text{xy} = \frac{92.74 + 0.94 + 39.43 + 89.11}{8} \\
#     s^2_\text{xy} = \frac{222.22}{8} \\
#     s^2_\text{xy} = 27.78
# \\
# \\
#     s_\text{xy} = \sqrt{27.78} \\
#     s_\text{xy} = 5.27
# \end{gather*}

# %% [markdown]
# > 4. A sample of book club members record the number of books they
# read last year. Calculate the mean number of books per member.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu = \frac{[(0)(25)] + [(1)(15)] + [(2)(18)] + [(3)(5)] + [(4)(12)] + [(5)(3)]}{25 + 15 + 18 + 5 + 12 + 3} \\
#         \mu = \frac{0 + 15 + 36 + 15 + 48 + 15}{78} \\
#         \mu = \frac{129}{78} \\
#         \mu = 1.65 \\
# \end{gather*}

# %% [markdown]
# > 5. The frequency distribution represents the number of pizza orders a
# local pizza restaurant received each day over the last $20$ days. Calculate
# the weighted sample mean, variance, and standard deviation.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         (5, 7): 5, (8, 10): 4, (11, 13): 4, (14, 16): 3, (17, 19): 3, (20, 22): 1 \\
# \\
#         \bar{\text{x}} = \frac{[(5)(6)] + [(4)(9)] + [(4)(12)] + [(3)(15)] + [(3)(18)] + [(1)(21)]}{5 + 4 + 4 + 3 + 3 + 1} \\
#         \bar{\text{x}} = \frac{30 + 36 + 48 + 45 + 54 + 21}{20} \\
#         \bar{\text{x}} = \frac{234.0}{20} \\
#         \bar{\text{x}} = 11.7
# \\
# \\
#         s^2_\text{xy} = \frac{[5(6.0 - 11.7)^2] + [4(9.0 - 11.7)^2] + [4(12.0 - 11.7)^2] + [3(15.0 - 11.7)^2] + [3(18.0 - 11.7)^2] + [1(21.0 - 11.7)^2]}{(5 + 4 + 4 + 3 + 3 + 1) - 1} \\
#         s^2_\text{xy} = \frac{[5(-5.7)^2] + [4(-2.7)^2] + [4(0.3)^2] + [3(3.3)^2] + [3(6.3)^2] + [1(9.3)^2]}{20 - 1} \\
#         s^2_\text{xy} = \frac{(5)(32.49) + (4)(7.29) + (4)(0.09) + (3)(10.89) + (3)(39.69) + (1)(86.49)}{19} \\
#         s^2_\text{xy} = \frac{162.45 + 29.16 + 0.36 + 32.67 + 119.07 + 86.49}{19} \\
#         s^2_\text{xy} = \frac{430.2}{19} \\
#         s^2_\text{xy} = 22.64
# \\
# \\
#         s_\text{xy} = \sqrt{22.64} \\
#         s_\text{xy} = 4.76
# \end{gather*}

# %% [markdown]
# > 6. Use the sample data to find the mean, variance, and standard
# deviation of commute time.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         (1, 5): 1, (6, 10): 4, (11, 15): 6, (16, 20): 3, (21, 25): 10, (26, 30): 13 \\
# \\
#         \bar{\text{x}} = \frac{[(1)(3)] + [(4)(8)] + [(6)(13)] + [(3)(18)] + [(10)(23)] + [(13)(28)]}{1 + 4 + 6 + 3 + 10 + 13} \\
#         \bar{\text{x}} = \frac{3 + 32 + 78 + 54 + 230 + 364}{37} \\
#         \bar{\text{x}} = \frac{761.0}{37} \\
#         \bar{\text{x}} = 20.57
# \\
# \\
#         s^2_\text{xy} = \frac{[1(3.0 - 20.57)^2] + [4(8.0 - 20.57)^2] + [6(13.0 - 20.57)^2] + [3(18.0 - 20.57)^2] + [10(23.0 - 20.57)^2] + [13(28.0 - 20.57)^2]}{(1 + 4 + 6 + 3 + 10 + 13) - 1} \\
#         s^2_\text{xy} = \frac{[1(-17.57)^2] + [4(-12.57)^2] + [6(-7.57)^2] + [3(-2.57)^2] + [10(2.43)^2] + [13(7.43)^2]}{37 - 1} \\
#         s^2_\text{xy} = \frac{(1)(308.7) + (4)(158.0) + (6)(57.3) + (3)(6.6) + (10)(5.9) + (13)(55.2)}{36} \\
#         s^2_\text{xy} = \frac{308.7 + 632.02 + 343.83 + 19.81 + 59.05 + 717.66}{36} \\
#         s^2_\text{xy} = \frac{2081.08}{36} \\
#         s^2_\text{xy} = 57.81
# \\
# \\
#         s_\text{xy} = \sqrt{57.81} \\
#         s_\text{xy} = 7.6
# \end{gather*}
