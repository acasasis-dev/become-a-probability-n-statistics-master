# %% [markdown]
# ## Exercise 3: Symmetric and Skewed Distributions and Outliers

# %% [markdown]
# > 1. Which type of distribution is modeled in the box plot (symmetric,
# negatively skewed, or positively skewed)?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Symmetric

# %% [markdown]
# > 2. Which type of distribution is modeled in the box plot (symmetric,
# negatively skewed, or positively skewed)?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Positively Skewed

# %% [markdown]
# > 3. The ages (in months) that babies spoke for the first time are
#
# ![image.png](attachment:image.png)
#
# Are there outliers in the data set? If so, state what they are. What is the
# best measure of central tendency for the data? What is the best measure
# of spread?

# %% [markdown]
# \begin{gather*}
#     \text{low outlier threshold} = 10 - 1.5(18.5 - 10) \\
#     \text{low outlier threshold} = 10 - 1.5(8.5) \\
#     \text{low outlier threshold} = 10 - 12.75 \\
#     \text{low outlier threshold} = -2.75 \\ \\
#
#     \text{high outlier threshold} = 18.5 + 1.5(8.5) \\
#     \text{high outlier threshold} = 18.5 + 12.75 \\
#     \text{high outlier threshold} = 31.25
# \end{gather*}
#
# There are no outliers in the dataset.

# %% [markdown]
# > 4. The number of text messages sent each day by Lucy’s mom is
#
# ![image.png](attachment:image.png)
#
# Are there outliers in the data set? If so, state what they are. What is the
# best measure of central tendency for the data? What is the best measure
# of spread?

# %% [markdown]
# > 5. Describe the shape, center, and spread of the data. State if there are
# outliers and what they are if they exist.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 6. Describe the shape, center and spread of the data. State if there are
# outliers and what they are if they exist.
#
# ![image.png](attachment:image.png)
