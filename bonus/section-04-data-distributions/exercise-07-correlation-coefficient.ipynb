# %% [markdown]
# ## Exercise 7: Correlation Coefficient

# %% [markdown]
# > 1. Calculate the correlation coefficient of the newborns‘ weight and body
# length, and then interpret the result.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu_\text{Weight} = \frac{3.55 + 4.01 + 3.05 + 5.35 + 4.22 + 6.12 + 7.45 + 5.95 + 6.35 + 6.98}{10} = \frac{53.03}{10} = 5.3 \\
#         \mu_\text{Body Length} = \frac{51 + 54 + 50 + 60 + 52 + 61 + 63 + 59 + 68 + 74}{10} = \frac{592}{10} = 59.2 \\
#         \\
#         Cov[\text{Weight}, \text{Body Length}] = \frac{(-1.75)(-8.2) + (-1.29)(-5.2) + (-2.25)(-9.2) + (0.05)(0.8) + (-1.08)(-7.2) + (0.82)(1.8) + (2.15)(3.8) + (0.65)(-0.2) + (1.05)(8.8) + (1.68)(14.8)}{10} \\
#         Cov[\text{Weight}, \text{Body Length}] = \frac{14.35 + 6.71 + 20.7 + 0.04 + 7.78 + 1.48 + 8.17 + -0.13 + 9.24 + 24.86}{10} \\
#         Cov[\text{Weight}, \text{Body Length}] = \frac{93.2}{10} \\
#         Cov[\text{Weight}, \text{Body Length}] = 9.32
# \\
# \\
#         \mu_\text{[Weight, Body Length]} = \frac{3.55 + 4.01 + 3.05 + 5.35 + 4.22 + 6.12 + 7.45 + 5.95 + 6.35 + 6.98}{10} = \frac{53.03}{10} = 5.3 \\
#         \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{(3.55 - 5.3)^2 + (4.01 - 5.3)^2 + (3.05 - 5.3)^2 + (5.35 - 5.3)^2 + (4.22 - 5.3)^2 + (6.12 - 5.3)^2 + (7.45 - 5.3)^2 + (5.95 - 5.3)^2 + (6.35 - 5.3)^2 + (6.98 - 5.3)^2}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{(-1.75)^2 + (-1.29)^2 + (-2.25)^2 + (0.05)^2 + (-1.08)^2 + (0.82)^2 + (2.15)^2 + (0.65)^2 + (1.05)^2 + (1.68)^2}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{3.06 + 1.66 + 5.06 + 0.0 + 1.17 + 0.67 + 4.62 + 0.42 + 1.1 + 2.82}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{20.58}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  2.06
# \\
#         \sigma_\text{[Weight, Body Length]} =  \sqrt{2.06} \\
#         \sigma_\text{[Weight, Body Length]} =  1.44 \\
# \\
#         \mu_\text{[Weight, Body Length]} = \frac{51 + 54 + 50 + 60 + 52 + 61 + 63 + 59 + 68 + 74}{10} = \frac{592}{10} = 59.2 \\
#         \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{(51 - 59.2)^2 + (54 - 59.2)^2 + (50 - 59.2)^2 + (60 - 59.2)^2 + (52 - 59.2)^2 + (61 - 59.2)^2 + (63 - 59.2)^2 + (59 - 59.2)^2 + (68 - 59.2)^2 + (74 - 59.2)^2}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{(-8.2)^2 + (-5.2)^2 + (-9.2)^2 + (0.8)^2 + (-7.2)^2 + (1.8)^2 + (3.8)^2 + (-0.2)^2 + (8.8)^2 + (14.8)^2}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{67.24 + 27.04 + 84.64 + 0.64 + 51.84 + 3.24 + 14.44 + 0.04 + 77.44 + 219.04}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  \frac{545.6}{10} \\
#         \sigma^2_\text{[Weight, Body Length]} =  54.56
# \\
#         \sigma_\text{[Weight, Body Length]} =  \sqrt{54.56} \\
#         \sigma_\text{[Weight, Body Length]} =  7.39 \\
# \\
#         \rho_\text{[Weight, Body Length]} = \frac{9.32}{(1.44)(7.39)} \\
#         \rho_\text{[Weight, Body Length]} = \frac{9.32}{10.64} \\
#         \rho_\text{[Weight, Body Length]} = 0.88
# \end{gather*}

# %% [markdown]
# > 2. Oliver is wondering whether there’s a correlation between the number
# of hours his classmates studied to prepare for the exam and their exam
# scores. He surveyed five classmates and recorded the data in a table.
# Calculate the correlation coefficient.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu_\text{Study hours} = \frac{6 + 2 + 11 + 7 + 5}{5} = \frac{31}{5} = 6.2 \\
#         \mu_\text{Exam score} = \frac{85 + 79 + 84 + 89 + 91}{5} = \frac{428}{5} = 85.6 \\
#         \\
#         Cov[\text{Study hours}, \text{Exam score}] = \frac{(-0.2)(-0.6) + (-4.2)(-6.6) + (4.8)(-1.6) + (0.8)(3.4) + (-1.2)(5.4)}{4} \\
#         Cov[\text{Study hours}, \text{Exam score}] = \frac{0.12 + 27.72 + -7.68 + 2.72 + -6.48}{4} \\
#         Cov[\text{Study hours}, \text{Exam score}] = \frac{16.4}{4} \\
#         Cov[\text{Study hours}, \text{Exam score}] = 4.1
# \\
# \\
#         \bar{\text{x}}_\text{[Study hours, Exam score]} = \frac{6 + 2 + 11 + 7 + 5}{5} = \frac{31}{5} = 6.2 \\
#         \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{(6 - 6.2)^2 + (2 - 6.2)^2 + (11 - 6.2)^2 + (7 - 6.2)^2 + (5 - 6.2)^2}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{(-0.2)^2 + (-4.2)^2 + (4.8)^2 + (0.8)^2 + (-1.2)^2}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{0.04 + 17.64 + 23.04 + 0.64 + 1.44}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{42.8}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  10.7
# \\
#         s_\text{[Study hours, Exam score]} =  \sqrt{10.7} \\
#         s_\text{[Study hours, Exam score]} =  3.27 \\
# \\
#         \bar{\text{x}}_\text{[Study hours, Exam score]} = \frac{85 + 79 + 84 + 89 + 91}{5} = \frac{428}{5} = 85.6 \\
#         \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{(85 - 85.6)^2 + (79 - 85.6)^2 + (84 - 85.6)^2 + (89 - 85.6)^2 + (91 - 85.6)^2}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{(-0.6)^2 + (-6.6)^2 + (-1.6)^2 + (3.4)^2 + (5.4)^2}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{0.36 + 43.56 + 2.56 + 11.56 + 29.16}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  \frac{87.2}{4} \\
#         s^2_\text{[Study hours, Exam score]} =  21.8
# \\
#         s_\text{[Study hours, Exam score]} =  \sqrt{21.8} \\
#         s_\text{[Study hours, Exam score]} =  4.67 \\
# \\
#         r_\text{[Study hours, Exam score]} = \frac{4.1}{(3.27)(4.67)} \\
#         r_\text{[Study hours, Exam score]} = \frac{4.1}{15.27} \\
#         r_\text{[Study hours, Exam score]} = 0.27
# \end{gather*}

# %% [markdown]
# > 3. Calculate the value of the Pearson correlation coefficient for the age,
# in years, and blood glucose levels, in mg/dL, then interpret the result.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu_\text{Age} = \frac{28 + 35 + 58 + 42 + 21 + 63 + 46}{7} = \frac{293}{7} = 41.86 \\
#         \mu_\text{Blood glucose} = \frac{101 + 93 + 95 + 105 + 93 + 89 + 100}{7} = \frac{676}{7} = 96.57 \\
#         \\
#         Cov[\text{Age}, \text{Blood glucose}] = \frac{(-13.86)(4.43) + (-6.86)(-3.57) + (16.14)(-1.57) + (0.14)(8.43) + (-20.86)(-3.57) + (21.14)(-7.57) + (4.14)(3.43)}{7} \\
#         Cov[\text{Age}, \text{Blood glucose}] = \frac{-61.4 + 24.49 + -25.34 + 1.18 + 74.47 + -160.03 + 14.2}{7} \\
#         Cov[\text{Age}, \text{Blood glucose}] = \frac{-132.43}{7} \\
#         Cov[\text{Age}, \text{Blood glucose}] = -18.92
# \\
# \\
#         \mu_\text{[Age, Blood glucose]} = \frac{28 + 35 + 58 + 42 + 21 + 63 + 46}{7} = \frac{293}{7} = 41.86 \\
#         \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{(28 - 41.86)^2 + (35 - 41.86)^2 + (58 - 41.86)^2 + (42 - 41.86)^2 + (21 - 41.86)^2 + (63 - 41.86)^2 + (46 - 41.86)^2}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{(-13.86)^2 + (-6.86)^2 + (16.14)^2 + (0.14)^2 + (-20.86)^2 + (21.14)^2 + (4.14)^2}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{192.1 + 47.06 + 260.5 + 0.02 + 435.14 + 446.9 + 17.14}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{1398.86}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  199.84
# \\
#         \sigma_\text{[Age, Blood glucose]} =  \sqrt{199.84} \\
#         \sigma_\text{[Age, Blood glucose]} =  14.14 \\
# \\
#         \mu_\text{[Age, Blood glucose]} = \frac{101 + 93 + 95 + 105 + 93 + 89 + 100}{7} = \frac{676}{7} = 96.57 \\
#         \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{(101 - 96.57)^2 + (93 - 96.57)^2 + (95 - 96.57)^2 + (105 - 96.57)^2 + (93 - 96.57)^2 + (89 - 96.57)^2 + (100 - 96.57)^2}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{(4.43)^2 + (-3.57)^2 + (-1.57)^2 + (8.43)^2 + (-3.57)^2 + (-7.57)^2 + (3.43)^2}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{19.62 + 12.74 + 2.46 + 71.06 + 12.74 + 57.3 + 11.76}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  \frac{187.68}{7} \\
#         \sigma^2_\text{[Age, Blood glucose]} =  26.81
# \\
#         \sigma_\text{[Age, Blood glucose]} =  \sqrt{26.81} \\
#         \sigma_\text{[Age, Blood glucose]} =  5.18 \\
# \\
#         \rho_\text{[Age, Blood glucose]} = \frac{-18.92}{(14.14)(5.18)} \\
#         \rho_\text{[Age, Blood glucose]} = \frac{-18.92}{73.25} \\
#         \rho_\text{[Age, Blood glucose]} = -0.26
# \end{gather*}

# %% [markdown]
# > 4. Maria likes discovering interesting correlations. She decides to choose
# random six days and record the data for shark attacks and ice cream sales
# in her coastal city. How should she interpret the correlation coefficient.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu_\text{Shark attacks} = \frac{4 + 2 + 8 + 11 + 5 + 9}{6} = \frac{39}{6} = 6.5 \\
#         \mu_\text{Ice cream sales} = \frac{38 + 30 + 55 + 61 + 38 + 42}{6} = \frac{264}{6} = 44 \\
#         \\
#         Cov[\text{Shark attacks}, \text{Ice cream sales}] = \frac{(-2.5)(-6) + (-4.5)(-14) + (1.5)(11) + (4.5)(17) + (-1.5)(-6) + (2.5)(-2)}{6} \\
#         Cov[\text{Shark attacks}, \text{Ice cream sales}] = \frac{15.0 + 63.0 + 16.5 + 76.5 + 9.0 + -5.0}{6} \\
#         Cov[\text{Shark attacks}, \text{Ice cream sales}] = \frac{175.0}{6} \\
#         Cov[\text{Shark attacks}, \text{Ice cream sales}] = 29.17
# \\
# \\
#         \mu_\text{[Shark attacks, Ice cream sales]} = \frac{4 + 2 + 8 + 11 + 5 + 9}{6} = \frac{39}{6} = 6.5 \\
#         \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{(4 - 6.5)^2 + (2 - 6.5)^2 + (8 - 6.5)^2 + (11 - 6.5)^2 + (5 - 6.5)^2 + (9 - 6.5)^2}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{(-2.5)^2 + (-4.5)^2 + (1.5)^2 + (4.5)^2 + (-1.5)^2 + (2.5)^2}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{6.25 + 20.25 + 2.25 + 20.25 + 2.25 + 6.25}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{57.5}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  9.58
# \\
#         \sigma_\text{[Shark attacks, Ice cream sales]} =  \sqrt{9.58} \\
#         \sigma_\text{[Shark attacks, Ice cream sales]} =  3.1 \\
# \\
#         \mu_\text{[Shark attacks, Ice cream sales]} = \frac{38 + 30 + 55 + 61 + 38 + 42}{6} = \frac{264}{6} = 44 \\
#         \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{(38 - 44)^2 + (30 - 44)^2 + (55 - 44)^2 + (61 - 44)^2 + (38 - 44)^2 + (42 - 44)^2}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{(-6)^2 + (-14)^2 + (11)^2 + (17)^2 + (-6)^2 + (-2)^2}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{36 + 196 + 121 + 289 + 36 + 4}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  \frac{682}{6} \\
#         \sigma^2_\text{[Shark attacks, Ice cream sales]} =  113.67
# \\
#         \sigma_\text{[Shark attacks, Ice cream sales]} =  \sqrt{113.67} \\
#         \sigma_\text{[Shark attacks, Ice cream sales]} =  10.66 \\
# \\
#         \rho_\text{[Shark attacks, Ice cream sales]} = \frac{29.17}{(3.1)(10.66)} \\
#         \rho_\text{[Shark attacks, Ice cream sales]} = \frac{29.17}{33.05} \\
#         \rho_\text{[Shark attacks, Ice cream sales]} = 0.88
# \end{gather*}

# %% [markdown]
# > 5. Calculate and interpret the correlation coefficient of the variables.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu_\text{Hand lenght, cm} = \frac{12 + 15 + 11 + 13 + 9 + 18 + 16 + 17}{8} = \frac{111}{8} = 13.88 \\
#         \mu_\text{Height, cm} = \frac{158 + 160 + 157 + 164 + 150 + 178 + 169 + 156}{8} = \frac{1292}{8} = 161.5 \\
#         \\
#         Cov[\text{Hand lenght, cm}, \text{Height, cm}] = \frac{(-1.88)(-3.5) + (1.12)(-1.5) + (-2.88)(-4.5) + (-0.88)(2.5) + (-4.88)(-11.5) + (4.12)(16.5) + (2.12)(7.5) + (3.12)(-5.5)}{8} \\
#         Cov[\text{Hand lenght, cm}, \text{Height, cm}] = \frac{6.58 + -1.68 + 12.96 + -2.2 + 56.12 + 67.98 + 15.9 + -17.16}{8} \\
#         Cov[\text{Hand lenght, cm}, \text{Height, cm}] = \frac{138.5}{8} \\
#         Cov[\text{Hand lenght, cm}, \text{Height, cm}] = 17.31
# \\
# \\
#         \mu_\text{[Hand lenght, cm, Height, cm]} = \frac{12 + 15 + 11 + 13 + 9 + 18 + 16 + 17}{8} = \frac{111}{8} = 13.88 \\
#         \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{(12 - 13.88)^2 + (15 - 13.88)^2 + (11 - 13.88)^2 + (13 - 13.88)^2 + (9 - 13.88)^2 + (18 - 13.88)^2 + (16 - 13.88)^2 + (17 - 13.88)^2}{8} \\
#
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{(-1.88)^2 + (1.12)^2 + (-2.88)^2 + (-0.88)^2 + (-4.88)^2 + (4.12)^2 + (2.12)^2 + (3.12)^2}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{3.53 + 1.25 + 8.29 + 0.77 + 23.81 + 16.97 + 4.49 + 9.73}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{68.84}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  8.61
# \\
#         \sigma_\text{[Hand lenght, cm, Height, cm]} =  \sqrt{8.61} \\
#         \sigma_\text{[Hand lenght, cm, Height, cm]} =  2.93 \\
# \\
#         \mu_\text{[Hand lenght, cm, Height, cm]} = \frac{158 + 160 + 157 + 164 + 150 + 178 + 169 + 156}{8} = \frac{1292}{8} = 161.5 \\
#         \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{(158 - 161.5)^2 + (160 - 161.5)^2 + (157 - 161.5)^2 + (164 - 161.5)^2 + (150 - 161.5)^2 + (178 - 161.5)^2 + (169 - 161.5)^2 + (156 - 161.5)^2}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{(-3.5)^2 + (-1.5)^2 + (-4.5)^2 + (2.5)^2 + (-11.5)^2 + (16.5)^2 + (7.5)^2 + (-5.5)^2}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{12.25 + 2.25 + 20.25 + 6.25 + 132.25 + 272.25 + 56.25 + 30.25}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  \frac{532.0}{8} \\
#         \sigma^2_\text{[Hand lenght, cm, Height, cm]} =  66.5
# \\
#         \sigma_\text{[Hand lenght, cm, Height, cm]} =  \sqrt{66.5} \\
#         \sigma_\text{[Hand lenght, cm, Height, cm]} =  8.15 \\
# \\
#         \rho_\text{[Hand lenght, cm, Height, cm]} = \frac{17.31}{(2.93)(8.15)} \\
#         \rho_\text{[Hand lenght, cm, Height, cm]} = \frac{17.31}{23.88} \\
#         \rho_\text{[Hand lenght, cm, Height, cm]} = 0.72
# \end{gather*}

# %% [markdown]
# > 6. Calculate and interpret the value of the correlation coefficient for the
# correlation between systolic blood pressure, in mmHg, and weight, in lbs.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         \mu_\text{SBP, mmHg} = \frac{138 + 125 + 145 + 156 + 132 + 148 + 160 + 135 + 150 + 155}{10} = \frac{1444}{10} = 144.4 \\
#         \mu_\text{Weight, lbs} = \frac{167 + 153 + 149 + 165 + 170 + 175 + 180 + 140 + 190 + 155}{10} = \frac{1644}{10} = 164.4 \\
#         \\
#         Cov[\text{SBP, mmHg}, \text{Weight, lbs}] = \frac{(-6.4)(2.6) + (-19.4)(-11.4) + (0.6)(-15.4) + (11.6)(0.6) + (-12.4)(5.6) + (3.6)(10.6) + (15.6)(15.6) + (-9.4)(-24.4) + (5.6)(25.6) + (10.6)(-9.4)}{10} \\
#         Cov[\text{SBP, mmHg}, \text{Weight, lbs}] = \frac{-16.64 + 221.16 + -9.24 + 6.96 + -69.44 + 38.16 + 243.36 + 229.36 + 143.36 + -99.64}{10} \\
#         Cov[\text{SBP, mmHg}, \text{Weight, lbs}] = \frac{687.4}{10} \\
#         Cov[\text{SBP, mmHg}, \text{Weight, lbs}] = 68.74
# \\
# \\
#         \mu_\text{[SBP, mmHg, Weight, lbs]} = \frac{138 + 125 + 145 + 156 + 132 + 148 + 160 + 135 + 150 + 155}{10} = \frac{1444}{10} = 144.4 \\
#         \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{(138 - 144.4)^2 + (125 - 144.4)^2 + (145 - 144.4)^2 + (156 - 144.4)^2 + (132 - 144.4)^2 + (148 - 144.4)^2 + (160 - 144.4)^2 + (135 - 144.4)^2 + (150 - 144.4)^2 + (155 - 144.4)^2}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{(-6.4)^2 + (-19.4)^2 + (0.6)^2 + (11.6)^2 + (-12.4)^2 + (3.6)^2 + (15.6)^2 + (-9.4)^2 + (5.6)^2 + (10.6)^2}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{40.96 + 376.36 + 0.36 + 134.56 + 153.76 + 12.96 + 243.36 + 88.36 + 31.36 + 112.36}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{1194.4}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  119.44
# \\
#         \sigma_\text{[SBP, mmHg, Weight, lbs]} =  \sqrt{119.44} \\
#         \sigma_\text{[SBP, mmHg, Weight, lbs]} =  10.93 \\
# \\
#         \mu_\text{[SBP, mmHg, Weight, lbs]} = \frac{167 + 153 + 149 + 165 + 170 + 175 + 180 + 140 + 190 + 155}{10} = \frac{1644}{10} = 164.4 \\
#         \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{(167 - 164.4)^2 + (153 - 164.4)^2 + (149 - 164.4)^2 + (165 - 164.4)^2 + (170 - 164.4)^2 + (175 - 164.4)^2 + (180 - 164.4)^2 + (140 - 164.4)^2 + (190 - 164.4)^2 + (155 - 164.4)^2}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{(2.6)^2 + (-11.4)^2 + (-15.4)^2 + (0.6)^2 + (5.6)^2 + (10.6)^2 + (15.6)^2 + (-24.4)^2 + (25.6)^2 + (-9.4)^2}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{6.76 + 129.96 + 237.16 + 0.36 + 31.36 + 112.36 + 243.36 + 595.36 + 655.36 + 88.36}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  \frac{2100.4}{10} \\
#         \sigma^2_\text{[SBP, mmHg, Weight, lbs]} =  210.04
# \\
#         \sigma_\text{[SBP, mmHg, Weight, lbs]} =  \sqrt{210.04} \\
#         \sigma_\text{[SBP, mmHg, Weight, lbs]} =  14.49 \\
# \\
#         \rho_\text{[SBP, mmHg, Weight, lbs]} = \frac{68.74}{(10.93)(14.49)} \\
#         \rho_\text{[SBP, mmHg, Weight, lbs]} = \frac{68.74}{158.38} \\
#         \rho_\text{[SBP, mmHg, Weight, lbs]} = 0.43
# \end{gather*}
