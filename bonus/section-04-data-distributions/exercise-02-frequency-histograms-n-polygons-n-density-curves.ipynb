# %% [markdown]
# ## Exercise 02: Frequency Histograms and Polygons, and Density Curves

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# > 1. A dog walking company keeps track of how many times each dog
# receives a walk. $40\%$ of all the dogs walked by the company received
# between $25$ and $40$ walks, and no dogs received more than $40$ walks. How
# many dogs received between $0$ and $25$ walks, if the company walks $400$
# dogs?

# %% [markdown]
# That would be $60\%$ and $60\%$ of $400$ is $240$.

# %% [markdown]
# > 2. The number of crayons in each student’s pencil box is
#
# ![image.png](attachment:image.png)
#
# Complete the frequency and relative frequency tables for the data and use
# it to create a relative frequency histogram.
#
# ![image-2.png](attachment:image-2.png)

# %%
cols = ['Frequency', 'Relative Frequency']
rows = ['1-5', '6-10', '11-15', '16-20', 'Totals']
data = [
	[4, '25%'],
	[1, '6.25%'],
	[5, '31.25'],
	[6, '37.5'],
	[16, '100%'],
]

fig, ax = plt.subplots()
ax.axis('off')

table = plt.table(
	colLabels=cols,
	rowLabels=rows,
	cellText=data,
	loc='center',
	cellLoc='center',
)

plt.show()

# %% [markdown]
# > 3. The table shows the scores on the last history exam in Mr. Ru’s class.
#
# ![image.png](attachment:image.png)
#
# Complete the relative frequency table and create a frequency polygon for
# the data.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > 4. Becky kept track of the number of ducks she saw at her
# neighborhood pond at $6 : 30$ a.m. every morning for $365$ days. On how
# many days did Becky see more than $5$ ducks?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 5. What percentage of the population is greater than $x$ for the density
# curve?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > 6. What percentage of the area in the density curve is between $3$ and $5$?
#
# ![image.png](attachment:image.png)
