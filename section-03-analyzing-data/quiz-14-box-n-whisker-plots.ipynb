# %% [markdown]
# ## Quiz 14: Box and Whisker Plots

# %% [markdown]
# > 1. ![image.png](attachment:image.png)

# %% [markdown]
# The median is $7.5$

# %% [markdown]
# > 2. ![image.png](attachment:image.png)

# %% [markdown]
# - Min: $0$
# - Q1: $10$
# - Median: $15$
# - Q3: $25$
# - Max: $35$

# %% [markdown]
# > 3. ![image.png](attachment:image.png)

# %% [markdown]
# **ANSWER: D**
