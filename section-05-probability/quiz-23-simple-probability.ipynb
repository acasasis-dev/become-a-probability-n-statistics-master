# %% [markdown]
# ## Quiz 23: Simple Probability

# %% [markdown]
# > 1. ![image.png](attachment:image.png)

# %% [markdown]
# **ANSWER: Should only be A and C**

# %% [markdown]
# > 2. ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         P(\text{Coconut Chocolate}) = \frac{2}{2 + 3 + 4 + 1} = \frac{2}{10} = 0.2 = 20.0\% \\
# \end{gather*}

# %% [markdown]
# > 3. ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#         P(\text{Whale}) = \frac{4}{4 + 6 + 1 + 3} = \frac{4}{14} = 0.29 = 29.0\% \\
# \end{gather*}
