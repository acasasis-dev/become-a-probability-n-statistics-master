# %% [markdown]
# ## Quiz 18: Normal Distributions and Z-Scores

# %% [markdown]
# > 1. ![image.png](attachment:image.png)

# %% [markdown]
# $95\%$ of values fall between $94$ and $206$

# %% [markdown]
# > 2. ![image.png](attachment:image.png)

# %% [markdown]
# Since it's the $+1$ z-score, it's gonna be $50\%$ plus half of $68\%$ which is $84\%$

# %% [markdown]
# > 3. ![image.png](attachment:image.png)

# %% [markdown]
# \begin{gather*}
#     14 - (\sigma * 0.8) = 12 \\
#     \sigma * 0.8 = 14 - 12 \\
#     \sigma * 0.8 = 2 \\
#     \frac{\sigma * 0.8 = 2}{0.8} \\
#     \sigma = 2.5
# \end{gather*}
