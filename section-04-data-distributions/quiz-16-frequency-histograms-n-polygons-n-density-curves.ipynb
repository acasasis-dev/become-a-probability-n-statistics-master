# %% [markdown]
# ## Quiz 16: Frequency Histograms and Polygons, and Density Curves

# %% [markdown]
# > 1. ![image.png](attachment:image.png)

# %% [markdown]
# $10$ as the minimum can be $0$ and maximum is $100$ which is divisible by $10$

# %% [markdown]
# > 2. ![image.png](attachment:image.png)

# %% [markdown]
# Only $1$ time.

# %% [markdown]
# > 3. ![image.png](attachment:image.png)

# %% [markdown]
# $10\%$ of the 3rd graders read $18 - 20$. Since there are $50$ 3rd graders in total, $10\%$ of $50$ is $5$
